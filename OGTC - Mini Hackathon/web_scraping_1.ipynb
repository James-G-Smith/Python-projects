# %%
import bs4
import requests

###############################################################################

link = ("https://www.ogauthority.co.uk/lessons-learned/index.html")
data = requests.get(link)
soup = bs4.BeautifulSoup(data.content, 'html.parser')

print(soup)

# Getting the text from the intorduction page "This microsite summarises..."
#maintext = soup.find_all("p")

#print(maintext[0].text)
# Out:
# <!DOCTYPE doctype html>
#
# <html class="no-js" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Decommissioning | The Oil &amp; Gas Authority | Decommissioning Learning 2018</title>
# <link href="css/foundation.css" rel="stylesheet"/>
# <link href="css/app.css" rel="stylesheet"/>
# </head>
# <body class="workflow">
# <div class="grid-container">
# <div class="hide-for-large-only hide-for-large medium-12 small-12 small-logo">
# <div class="grid-x grid-padding-x"><a href="index.html"><img alt="Oil &amp; Gas Authority" src="images/Oil-Gas-Authority.png"/></a>
# </div>
# </div>
# <!-- Sections Menu -->
# <div class="large-12 cell top-menu">
# <div class="grid-x">
# <div class="large-7 medium-12 small-12">
# <div class="grid-x grid-padding-x">
# <div class="cell cell-first large-auto medium-auto small-2"><a href="1/planning/operating-pm.html"><img alt="1 - Operating" height="300" src="images/1_Tab_Operating.png" width="230"/></a></div>
# <div class="cell large-auto medium-auto small-2"><a href="2/planning/warm-phase-wa.html"><img alt="2 - Warm Phase" height="300" src="images/2_Tab_Warm_Phase.png" width="230"/></a></div>
# <div class="cell large-auto medium-auto small-2"><a href="3/planning/cold-phase-tp.html"><img alt="3 - Cold Phase" height="300" src="images/3_Tab_Cold_Phase.png" width="230"/></a></div>
# <div class="cell large-auto medium-auto small-2"><a href="4/execution/removal-froc.html"><img alt="4 - Removal" height="300" src="images/4_Tab_Removal.png" width="230"/></a></div>
# <div class="cell large-auto medium-auto small-2"><a href="4/execution/removal-froc.html"><img alt="5 - Dismantle &amp; Dispose" height="300" src="images/5_Tab_Dismantle.png" width="230"/></a></div>
# <div class="cell large-auto medium-auto small-2"><a href="6/execution/monitoring-m.html"><img alt="6 - Monitoring" height="300" src="images/6_Tab_Monitoring.png" width="230"/></a></div>
# </div>
# </div>
# <div class="large-1 medium-12 small-12">
# <div class="grid-x grid-padding-x">
# <div class="cell large-auto medium-auto small-auto">    </div>
# </div>
# </div>
# <div class="large-4 hide-for-medium-only hide-for-small-only logo">
# <div class="grid-x grid-padding-x">
# <div class="cell large-auto medium-auto small-auto"><a href="index.html"><img alt="Oil &amp; Gas Authority" src="images/Oil-Gas-Authority.png"/></a></div>
# </div>
# </div>
# </div>
# </div>
# <!-- Topics Menu -->
# <div class="grid-x grid-padding-x">
# <div class="large-12 cell">
# <div class="headline">
# <div class="grid-x grid-padding-x">
# <div class="large-12 medium-12 small-12 cell">
# <h1 class="section-title"><a href="1/planning/operating-pm.html">Decommissioning<br/>
#            		    Workflow</a></h1>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Topic Content -->
# <div class="grid-x grid-padding-x">
# <div class="large-12 cell">
# <div class="">
# <div class="grid-x grid-padding-x">
# <div class="large-7 medium-5 small-12 cell">
# <h2 class="topic-title">The Oil &amp; Gas Authority</h2>
# <h3 class="topic-subtitle">Decommissioning Learning  2018</h3>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid-x grid-padding-x">
# <div class="large-12 cell">
# <div class="">
# <div class="grid-x grid-padding-x">
# <div class="large-6 medium-10 small-10 cell spacer">
# <p>This microsite summarises still-evolving learnings perceived to improve decommissioning cost-effectiveness. Though the applicability / effectiveness of these will vary, the options listed will typically merit consideration.</p>
# <p> </p>
# </div>
# <div class="large-1 medium-2 small-2 cell"><a href="1/planning/operating-pm.html"><img alt="Start" class="arrow" height="150" src="images/start-arrow.png" width="120"/></a>
# </div> </div>
# </div>
# </div>
# </div>
# <div class="large-12 cell">
# <div class="grid-x grid-padding-x feedback">
# <div class="large-10 cell"></div>
# <div class="large-2 cell">
# <a href="feedback.html">Feedback <img alt="Feedback" src="images/feedback.png"/></a>
# </div>
# </div>
# </div>
# </div>
# <script src="js/vendor/jquery.js"></script>
# <script src="js/vendor/what-input.js"></script>
# <script src="js/vendor/foundation.js"></script>
# <script src="js/app.js"></script>
# </body>
# </html>
